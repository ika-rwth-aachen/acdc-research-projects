# %%
from convert_npz_to_png import *

# %%
file_path = 'example_npz_to_png/input_files'
output_path = 'example_npz_to_png/output_images'
image_path = 'example_npz_to_png/input_files/example_image_0.npz'

# %%
converter = File_to_Image()

# %%
converter.store_images(file_path, output_path)
# Out:
# Images placed in example_npz_to_png/output_images

# %%
converter.print_converted_image(image_path)
